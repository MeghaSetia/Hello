# %% [markdown]
# # Web-scraping
#
# A lot of times, data in structured format is not available to us and we need to depend on data from web-pages for our analysis purposes.
#
# Suppose, you wanted to perform prepare a list of products an e-retailer like Amazon sells in the Mobile Phone Category and compare the same with another one, say Flipkart.
#
# Alternatively, you may want to list down the retail house prices of Delhi and establish a relationship with the living square feet area.
#
# You may not be able to find a structured datasets for such tasks and have to rely on scraping data from different websites to come up with cwrtain answers to questions posed.
#
# Today will be look at an example of how to perform web-scraping with Python using a library called beautifulsoup. This tutorial on web-scraping will help you to scrape data from different websites depending on the problem statement at hand.

# %% [markdown]
# # What is Web Scraping?
#
# - Automated method used to extract large amounts of data from websites.
# - Unstructured data to store it in a structured form
#
#
# # Legality of Web Scraping
#
# Talking about whether web scraping is legal or not, some websites allow web scraping and some don’t. To know whether a website allows web scraping or not, you can look at the website’s “robots.txt” file. You can find this file by appending “/robots.txt” to the URL that you want to scrape. For this example, I am scraping Flipkart website. So, to see the “robots.txt” file, the URL is
# www.flipkart.com/robots.txt.
#
# Read this blog about legalities: https://prowebscraper.com/blog/is-web-scraping-legal/

# %% [markdown]
# # Steps in Web- Scraping
#
# - Find the url you want to scrape. Let's try the mobile phone listing of Flipkart.
#
# - Inspect webpages: The data is usually nested in tags. So, we inspect the page to see, under which tag the data we want to scrape is nested.
#
# - Find the data you want to extract
#
# - Install chromedriver
#
# ![image.png](data:image/png;base64,...)

# %%
# !pip install selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome("chromedriver_win32/chromedriver.exe")

# %%
products=[] #List to store name of the product
prices=[] #List to store price of the product
ratings=[] #List to store rating of the product


driver.get("https://www.flipkart.com/mobiles/mi~brand/pr?sid=tyy,4io&otracker=nmenu_sub_Electronics_0_Mi")

# %%
content = driver.page_source
soup = BeautifulSoup(content)
products=[]
prices=[]
for a in soup.findAll('div', attrs = {'class':'_3O0U0u'}):
    name=a.find('div', attrs={'class':'_3wU53n'})
    print(name)
    price=a.find('div', attrs={'class':'_1vC4OE _2rQ-NK'})
    products.append(name.text)
    prices.append(price.text)
# Out:
# <div class="_3wU53n">Redmi 8 (Emerald Green, 64 GB)</div>
# <div class="_3wU53n">Redmi 8 (Onyx Black, 64 GB)</div>
# <div class="_3wU53n">Redmi 8 (Sapphire Blue, 64 GB)</div>
# <div class="_3wU53n">Redmi 8A Dual (Midnight Grey, 64 GB)</div>
# <div class="_3wU53n">Redmi Note 8 (Neptune Blue, 64 GB)</div>
# <div class="_3wU53n">Redmi Note 8 (Moonlight White, 64 GB)</div>
# <div class="_3wU53n">Redmi Note 8 (Cosmic Purple, 128 GB)</div>
# <div class="_3wU53n">Redmi 8A Dual (Sea Blue, 64 GB)</div>
# <div class="_3wU53n">Redmi Note 8 (Space Black, 64 GB)</div>
# <div class="_3wU53n">Redmi Note 8 (Space Black, 128 GB)</div>
# <div class="_3wU53n">Redmi 8A Dual (Sea Blue, 32 GB)</div>
# <div class="_3wU53n">Redmi 8A Dual (Midnight Grey, 32 GB)</div>
# <div class="_3wU53n">Redmi Note 7 Pro (Space Black, 128 GB)</div>
# <div class="_3wU53n">Redmi Note 8 (Neptune Blue, 128 GB)</div>
# <div class="_3wU53n">Mi A3 (Kind of Grey, 128 GB)</div>
# ...

# %%
len(products)
# Out:
# 24

# %%
len(prices)
# Out:
# 24

# %%
# df = pd.DataFrame({'Product Name':products, 'Price':prices})

# %% [markdown]
# # Task
#
# I will divide you into 3 groups of 3 people each. Your task would be to think about an analysis you would want to perform. It could be anything ranging from price comparisons, socio-economic analysis or anything else. This will be part of a long term-project that will help you to build your profile as a data scientist. To start-off this project, the task for the upcoming week would be brainstorm about what problem you would want to solve being a data-scientist, web-scrape data for the purpose of the analysis, structure the data in a format that you think would be applicable for the purposes of the proect and present your understanding of the data to us. We will apply specific Machine Learning/AI techniques on the data as we learn about those over the coming period.
